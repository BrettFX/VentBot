# %%
import xml.etree.ElementTree as ET
import pandas as pd
DATA = "./data/Jack_Test1.xml"

# %%
e = ET.parse(DATA).getroot()

# %%
elements = e.findall('sms')
elements
# Out:
# [<Element 'sms' at 0x000001D19480C4F8>,
#  <Element 'sms' at 0x000001D19480CA48>,
#  <Element 'sms' at 0x000001D19480CAE8>,
#  <Element 'sms' at 0x000001D19480CB38>,
#  <Element 'sms' at 0x000001D19480CB88>,
#  <Element 'sms' at 0x000001D19480CBD8>,
#  <Element 'sms' at 0x000001D19480CC28>,
#  <Element 'sms' at 0x000001D19480CC78>,
#  <Element 'sms' at 0x000001D19480CCC8>,
#  <Element 'sms' at 0x000001D19480CD18>,
#  <Element 'sms' at 0x000001D19480CD68>,
#  <Element 'sms' at 0x000001D19480CDB8>,
#  <Element 'sms' at 0x000001D19480CE08>,
#  <Element 'sms' at 0x000001D19480CE58>,
#  <Element 'sms' at 0x000001D19480CEA8>,
#  <Element 'sms' at 0x000001D19480CEF8>,
#  <Element 'sms' at 0x000001D19480CF48>,
#  <Element 'sms' at 0x000001D19480CF98>,
#  <Element 'sms' at 0x000001D194821048>,
#  <Element 'sms' at 0x000001D194821098>,
#  <Element 'sms' at 0x000001D1948210E8>,
#  <Element 'sms' at 0x000001D194821138>,
#  <Element 'sms' at 0x000001D1948211D8>,
#  <Element 'sms' at 0x000001D194821228>,
#  <Element 'sms' at 0x000001D194821278>,
#  <Element 'sms' at 0x000001D1948212C8>,
#  <Element 'sms' at 0x000001D194821318>,
#  <Element 'sms' at 0x000001D194821368>,
#  <Element 'sms' at 0x000001D1948213B8>,
#  <Element 'sms' at 0x000001D194821408>,
#  <Element 'sms' at 0x000001D194821458>,
#  <Element 'sms' at 0x000001D1948214A8>,
#  <Element 'sms' at 0x000001D1948214F8>,
#  <Element 'sms' at 0x000001D194821548>,
#  <Element 'sms' at 0x000001D194821598>,
#  <Element 'sms' at 0x000001D1948215E8>,
#  <Element 'sms' at 0x000001D194821638>,
#  <Element 'sms' at 0x000001D194821688>,
#  <Element 'sms' at 0x000001D1948216D8>,
#  <Element 'sms' at 0x000001D194821728>,
#  <Element 'sms' at 0x000001D194821778>,
#  <Element 'sms' at 0x000001D1948217C8>,
#  <Element 'sms' at 0x000001D194821818>,
#  <Element 'sms' at 0x000001D194821868>,
#  <Element 'sms' at 0x000001D194821908>,
#  <Element 'sms' at 0x000001D194821958>,
#  <Element 'sms' at 0x000001D1948219F8>,
#  <Element 'sms' at 0x000001D194821A48>,
#  <Element 'sms' at 0x000001D194821AE8>,
#  <Element 'sms' at 0x000001D194821B38>,
#  <Element 'sms' at 0x000001D194821B88>,
#  <Element 'sms' at 0x000001D194821BD8>,
#  <Element 'sms' at 0x000001D194821C28>,
#  <Element 'sms' at 0x000001D194821C78>,
#  <Element 'sms' at 0x000001D194821CC8>,
#  <Element 'sms' at 0x000001D194821D18>,
#  <Element 'sms' at 0x000001D194821D68>,
#  <Element 'sms' at 0x000001D194821DB8>,
#  <Element 'sms' at 0x000001D194821E08>,
#  <Element 'sms' at 0x000001D194821E58>,
#  <Element 'sms' at 0x000001D194821EA8>,
#  <Element 'sms' at 0x000001D194821F48>,
#  <Element 'sms' at 0x000001D194821F98>,
#  <Element 'sms' at 0x000001D19482B048>,
#  <Element 'sms' at 0x000001D19482B098>,
#  <Element 'sms' at 0x000001D19482B0E8>,
#  <Element 'sms' at 0x000001D19482B188>,
#  <Element 'sms' at 0x000001D19482B1D8>,
#  <Element 'sms' at 0x000001D19482B278>,
#  <Element 'sms' at 0x000001D19482B2C8>,
#  <Element 'sms' at 0x000001D19482B368>,
#  <Element 'sms' at 0x000001D19482B3B8>,
#  <Element 'sms' at 0x000001D19482B408>,
#  <Element 'sms' at 0x000001D19482B458>,
#  <Element 'sms' at 0x000001D19482B4F8>,
#  <Element 'sms' at 0x000001D19482B548>,
#  <Element 'sms' at 0x000001D19482B598>,
#  <Element 'sms' at 0x000001D19482B5E8>,
#  <Element 'sms' at 0x000001D19482B638>,
#  <Element 'sms' at 0x000001D19482B688>,
#  <Element 'sms' at 0x000001D19482B6D8>,
#  <Element 'sms' at 0x000001D19482B728>,
#  <Element 'sms' at 0x000001D19482B778>,
#  <Element 'sms' at 0x000001D19482B7C8>,
#  <Element 'sms' at 0x000001D19482B818>,
#  <Element 'sms' at 0x000001D19482B868>,
#  <Element 'sms' at 0x000001D19482B8B8>,
#  <Element 'sms' at 0x000001D19482B908>,
#  <Element 'sms' at 0x000001D19482B9A8>,
#  <Element 'sms' at 0x000001D19482B9F8>,
#  <Element 'sms' at 0x000001D19482BA48>,
#  <Element 'sms' at 0x000001D19482BA98>,
#  <Element 'sms' at 0x000001D19482BAE8>,
#  <Element 'sms' at 0x000001D19482BB38>,
#  <Element 'sms' at 0x000001D19482BB88>,
#  <Element 'sms' at 0x000001D19482BBD8>,
#  <Element 'sms' at 0x000001D19482BC28>,
#  <Element 'sms' at 0x000001D19482BC78>,
#  <Element 'sms' at 0x000001D19482BCC8>,
#  <Element 'sms' at 0x000001D19482BD18>,
#  <Element 'sms' at 0x000001D19482BD68>,
#  <Element 'sms' at 0x000001D19482BDB8>,
#  <Element 'sms' at 0x000001D19482BE08>,
#  <Element 'sms' at 0x000001D19482BE58>,
#  <Element 'sms' at 0x000001D19482BEF8>,
#  <Element 'sms' at 0x000001D19482BF48>,
#  <Element 'sms' at 0x000001D194837048>,
#  <Element 'sms' at 0x000001D194837098>,
#  <Element 'sms' at 0x000001D1948370E8>,
#  <Element 'sms' at 0x000001D194837188>,
#  <Element 'sms' at 0x000001D1948371D8>,
#  <Element 'sms' at 0x000001D194837228>,
#  <Element 'sms' at 0x000001D1948372C8>,
#  <Element 'sms' at 0x000001D194837318>,
#  <Element 'sms' at 0x000001D194837368>,
#  <Element 'sms' at 0x000001D1948373B8>,
#  <Element 'sms' at 0x000001D194837408>,
#  <Element 'sms' at 0x000001D194837458>,
#  <Element 'sms' at 0x000001D1948374A8>,
#  <Element 'sms' at 0x000001D1948374F8>,
#  <Element 'sms' at 0x000001D194837548>,
#  <Element 'sms' at 0x000001D194837598>,
#  <Element 'sms' at 0x000001D1948375E8>,
#  <Element 'sms' at 0x000001D194837638>,
#  <Element 'sms' at 0x000001D194837688>,
#  <Element 'sms' at 0x000001D1948376D8>,
#  <Element 'sms' at 0x000001D194837728>,
#  <Element 'sms' at 0x000001D194837778>,
#  <Element 'sms' at 0x000001D1948377C8>,
#  <Element 'sms' at 0x000001D194837818>,
#  <Element 'sms' at 0x000001D194837868>,
#  <Element 'sms' at 0x000001D1948378B8>,
#  <Element 'sms' at 0x000001D194837908>,
#  <Element 'sms' at 0x000001D194837958>,
#  <Element 'sms' at 0x000001D1948379A8>,
#  <Element 'sms' at 0x000001D1948379F8>,
#  <Element 'sms' at 0x000001D194837A48>,
#  <Element 'sms' at 0x000001D194837A98>,
#  <Element 'sms' at 0x000001D194837AE8>,
#  <Element 'sms' at 0x000001D194837B38>,
#  <Element 'sms' at 0x000001D194837B88>,
#  <Element 'sms' at 0x000001D194837BD8>,
#  <Element 'sms' at 0x000001D194837C28>,
#  <Element 'sms' at 0x000001D194837C78>,
#  <Element 'sms' at 0x000001D194837CC8>,
#  <Element 'sms' at 0x000001D194837D18>,
#  <Element 'sms' at 0x000001D194837D68>,
#  <Element 'sms' at 0x000001D194837DB8>,
#  <Element 'sms' at 0x000001D194837E08>,
#  <Element 'sms' at 0x000001D194837E58>,
#  <Element 'sms' at 0x000001D194837EA8>,
#  <Element 'sms' at 0x000001D194837EF8>,
#  <Element 'sms' at 0x000001D194837F48>,
#  <Element 'sms' at 0x000001D194837F98>,
#  <Element 'sms' at 0x000001D194844048>,
#  <Element 'sms' at 0x000001D194844098>,
#  <Element 'sms' at 0x000001D194844138>,
#  <Element 'sms' at 0x000001D194844188>,
#  <Element 'sms' at 0x000001D1948441D8>,
#  <Element 'sms' at 0x000001D194844228>,
#  <Element 'sms' at 0x000001D194844278>,
#  <Element 'sms' at 0x000001D1948442C8>,
#  <Element 'sms' at 0x000001D194844318>,
#  <Element 'sms' at 0x000001D1948443B8>,
#  <Element 'sms' at 0x000001D194844408>,
#  <Element 'sms' at 0x000001D194844458>,
#  <Element 'sms' at 0x000001D1948444A8>,
#  <Element 'sms' at 0x000001D1948444F8>,
#  <Element 'sms' at 0x000001D194844548>,
#  <Element 'sms' at 0x000001D1948445E8>,
#  <Element 'sms' at 0x000001D194844638>,
#  <Element 'sms' at 0x000001D194844688>,
#  <Element 'sms' at 0x000001D1948446D8>,
#  <Element 'sms' at 0x000001D194844728>,
#  <Element 'sms' at 0x000001D194844778>,
#  <Element 'sms' at 0x000001D1948447C8>,
#  <Element 'sms' at 0x000001D194844818>,
#  <Element 'sms' at 0x000001D194844868>,
#  <Element 'sms' at 0x000001D1948448B8>,
#  <Element 'sms' at 0x000001D194844908>,
#  <Element 'sms' at 0x000001D194844958>,
#  <Element 'sms' at 0x000001D1948449A8>,
#  <Element 'sms' at 0x000001D1948449F8>,
#  <Element 'sms' at 0x000001D194844A48>,
#  <Element 'sms' at 0x000001D194844A98>,
#  <Element 'sms' at 0x000001D194844AE8>,
#  <Element 'sms' at 0x000001D194844B38>,
#  <Element 'sms' at 0x000001D194844BD8>,
#  <Element 'sms' at 0x000001D194844C28>,
#  <Element 'sms' at 0x000001D194844C78>,
#  <Element 'sms' at 0x000001D194844CC8>,
#  <Element 'sms' at 0x000001D194844D18>,
#  <Element 'sms' at 0x000001D194844D68>,
#  <Element 'sms' at 0x000001D194844DB8>,
#  <Element 'sms' at 0x000001D194844E08>,
#  <Element 'sms' at 0x000001D194844E58>,
#  <Element 'sms' at 0x000001D194844EA8>,
#  <Element 'sms' at 0x000001D194844F48>,
#  <Element 'sms' at 0x000001D194844F98>,
#  <Element 'sms' at 0x000001D19484E048>,
#  <Element 'sms' at 0x000001D19484E098>,
#  <Element 'sms' at 0x000001D19484E0E8>,
#  <Element 'sms' at 0x000001D19484E138>,
#  <Element 'sms' at 0x000001D19484E188>,
#  <Element 'sms' at 0x000001D19484E1D8>,
#  <Element 'sms' at 0x000001D19484E228>,
#  <Element 'sms' at 0x000001D19484E2C8>,
#  <Element 'sms' at 0x000001D19484E318>,
#  <Element 'sms' at 0x000001D19484E368>,
#  <Element 'sms' at 0x000001D19484E3B8>,
#  <Element 'sms' at 0x000001D19484E458>,
#  <Element 'sms' at 0x000001D19484E4A8>,
#  <Element 'sms' at 0x000001D19484E4F8>,
#  <Element 'sms' at 0x000001D19484E548>,
#  <Element 'sms' at 0x000001D19484E598>,
#  <Element 'sms' at 0x000001D19484E5E8>,
#  <Element 'sms' at 0x000001D19484E638>,
#  <Element 'sms' at 0x000001D19484E688>,
#  <Element 'sms' at 0x000001D19484E6D8>,
#  <Element 'sms' at 0x000001D19484E728>,
#  <Element 'sms' at 0x000001D19484E778>,
#  <Element 'sms' at 0x000001D19484E7C8>,
#  <Element 'sms' at 0x000001D19484E818>,
#  <Element 'sms' at 0x000001D19484E868>,
#  <Element 'sms' at 0x000001D19484E8B8>,
#  <Element 'sms' at 0x000001D19484E908>,
#  <Element 'sms' at 0x000001D19484E958>,
#  <Element 'sms' at 0x000001D19484E9A8>,
#  <Element 'sms' at 0x000001D19484E9F8>,
#  <Element 'sms' at 0x000001D19484EA48>,
#  <Element 'sms' at 0x000001D19484EA98>,
#  <Element 'sms' at 0x000001D19484EB38>,
#  <Element 'sms' at 0x000001D19484EB88>,
#  <Element 'sms' at 0x000001D19484EBD8>,
#  <Element 'sms' at 0x000001D19484EC78>,
#  <Element 'sms' at 0x000001D19484ECC8>,
#  <Element 'sms' at 0x000001D19484ED18>,
#  <Element 'sms' at 0x000001D19484ED68>,
#  <Element 'sms' at 0x000001D19484EDB8>,
#  <Element 'sms' at 0x000001D19484EE08>,
#  <Element 'sms' at 0x000001D19484EE58>,
#  <Element 'sms' at 0x000001D19484EEA8>,
#  <Element 'sms' at 0x000001D19484EEF8>,
#  <Element 'sms' at 0x000001D19484EF48>,
#  <Element 'sms' at 0x000001D19484EF98>,
#  <Element 'sms' at 0x000001D19485E048>,
#  <Element 'sms' at 0x000001D19485E098>,
#  <Element 'sms' at 0x000001D19485E0E8>,
#  <Element 'sms' at 0x000001D19485E138>,
#  <Element 'sms' at 0x000001D19485E188>,
#  <Element 'sms' at 0x000001D19485E1D8>,
#  <Element 'sms' at 0x000001D19485E228>,
#  <Element 'sms' at 0x000001D19485E278>,
#  <Element 'sms' at 0x000001D19485E2C8>,
#  <Element 'sms' at 0x000001D19485E318>,
#  <Element 'sms' at 0x000001D19485E368>,
#  <Element 'sms' at 0x000001D19485E3B8>,
#  <Element 'sms' at 0x000001D19485E408>,
#  <Element 'sms' at 0x000001D19485E458>,
#  <Element 'sms' at 0x000001D19485E4A8>]

# %%
for attributes in elements:
    for key in attributes.keys():
        print(attributes[key])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-ce71a15a370b> in <module>()
#       1 for attributes in elements:
#       2     for key in attributes.keys():
# ----> 3         print(attributes[key])
#
# TypeError: element indices must be integers

# %%
class XML2DataFrame:

    def __init__(self, xml_data):
        self.root = ET.XML(xml_data)

    def parse_root(self, root):
        return [self.parse_element(child) for child in iter(root)]

    def parse_element(self, element, parsed=None):
        if parsed is None:
            parsed = dict()
        for key in element.keys():
            parsed[key] = element.attrib.get(key)
        if element.text:
            parsed[element.tag] = element.text
        for child in list(element):
            self.parse_element(child, parsed)
        return parsed

    def process_data(self):
        structure_data = self.parse_root(self.root)
        return pd.DataFrame(structure_data)

# %%
xml2df = XML2DataFrame(DATA)
xml_dataframe = xml2df.process_data()
xml_dataframe
# Out:
# Traceback (most recent call last):
#
#   File "c:\users\brett\appdata\local\programs\python\python36\lib\site-packages\IPython\core\interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-4-966adc262a5b>", line 1, in <module>
#     xml2df = XML2DataFrame(DATA)
#
#   File "<ipython-input-2-0c364e01c6ca>", line 4, in __init__
#     self.root = ET.XML(xml_data)
#
#   File "c:\users\brett\appdata\local\programs\python\python36\lib\xml\etree\ElementTree.py", line 1314, in XML
#     parser.feed(text)
#
#   File "<string>", line unknown
# ParseError: not well-formed (invalid token): line 1, column 1
